# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import library

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import missingno as msno
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error 
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# # **Read Data**

# %%
path = "/content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/movies_1991_2020.csv"
df = pd.read_csv(path)
df = df.drop(columns='Unnamed: 0')
df.head(5)
# Out:
#                             name  year          director  ...  war  west  non_t
# 0       The Silence of the Lambs  1991    Jonathan Demme  ...    0     0      0
# 1     Terminator 2: Judgment Day  1991     James Cameron  ...    0     0      0
# 2           Beauty and the Beast  1991    Gary Trousdale  ...    0     0      0
# 3                           Hook  1991  Steven Spielberg  ...    0     0      0
# 4  Robin Hood: Prince of Thieves  1991    Kevin Reynolds  ...    0     0      0
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12161 entries, 0 to 12160
# Data columns (total 34 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      12161 non-null  object
#  1   year      12161 non-null  int64
#  2   director  12150 non-null  object
#  3   rating    12161 non-null  float64
#  4   m_score   8274 non-null   float64
#  5   vote      11016 non-null  float64
#  6   gross     11016 non-null  float64
#  7   act       12161 non-null  int64
#  8   advent    12161 non-null  int64
#  9   anima     12161 non-null  int64
#  10  biogr     12161 non-null  int64
#  11  come      12161 non-null  int64
#  12  crime     12161 non-null  int64
#  13  docum     12161 non-null  int64
#  14  dram      12161 non-null  int64
#  15  fami      12161 non-null  int64
#  16  fant      12161 non-null  int64
#  17  film_nor  12161 non-null  int64
#  18  game_sh   12161 non-null  int64
#  19  hist      12161 non-null  int64
#  20  horr      12161 non-null  int64
#  21  mus       12161 non-null  int64
#  22  musc      12161 non-null  int64
#  23  myst      12161 non-null  int64
#  24  news      12161 non-null  int64
#  25  real_tv   12161 non-null  int64
#  26  rom       12161 non-null  int64
#  27  sci_f     12161 non-null  int64
#  28  spo       12161 non-null  int64
#  29  talksh    12161 non-null  int64
#  30  thrill    12161 non-null  int64
#  31  war       12161 non-null  int64
#  32  west      12161 non-null  int64
#  33  non_t     12161 non-null  int64
# dtypes: float64(4), int64(28), object(2)
# memory usage: 3.2+ MB

# %% [markdown]
# # **Data Visualization**

# %%
df.columns
# Out:
# Index(['name', 'year', 'director', 'rating', 'm_score', 'vote', 'gross', 'act',
#        'advent', 'anima', 'biogr', 'come', 'crime', 'docum', 'dram', 'fami',
#        'fant', 'film_nor', 'game_sh', 'hist', 'horr', 'mus', 'musc', 'myst',
#        'news', 'real_tv', 'rom', 'sci_f', 'spo', 'talksh', 'thrill', 'war',
#        'west', 'non_t'],
#       dtype='object')

# %%
var_year = 'year'
data = pd.concat([df['rating'], df[var_year]], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var_year, y="rating", data=data)
fig.axis(ymin=0, ymax=10);
plt.xticks(rotation=90);

# %%
dr_list = ['name', 'year', 'director']
df = df.drop(dr_list, axis=1)
df.head(5)
# Out:
#    rating  m_score       vote        gross  ...  thrill  war  west  non_t
# 0     8.6     85.0  1294962.0  130742922.0  ...       1    0     0      0
# 1     8.5     75.0  1008750.0  204843350.0  ...       0    0     0      0
# 2     8.0     95.0   421130.0  218967620.0  ...       0    0     0      0
# 3     6.8     52.0   238177.0  119654823.0  ...       0    0     0      0
# 4     6.9     51.0   180551.0  165500000.0  ...       0    0     0      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#              rating      m_score  ...          west         non_t
# count  12161.000000  8274.000000  ...  12161.000000  12161.000000
# mean       6.257109    55.649746  ...      0.006003      0.004194
# std        1.067379    17.225767  ...      0.077248      0.064626
# min        1.400000     1.000000  ...      0.000000      0.000000
# 25%        5.700000    43.000000  ...      0.000000      0.000000
# 50%        6.400000    56.000000  ...      0.000000      0.000000
# 75%        7.000000    68.000000  ...      0.000000      0.000000
# max        9.400000   100.000000  ...      1.000000      1.000000
#
# [8 rows x 31 columns]

# %%
genres_cols = dict()
for col in df.columns[4:].values:
  genres_cols[col] = df[col].values.sum()

# %%
fig, ax = plt.subplots(figsize = (8,5.5), dpi=300)

plt.barh(*zip(*genres_cols.items()))
for i, v in enumerate(genres_cols):
    ax.text(genres_cols[v]+5, i-0.25, str(genres_cols[v]), color='blue',fontsize=8)

# %%
var_dram = 'dram'
data = pd.concat([df['rating'], df[var_dram].where(df[var_dram] > 0)], axis=1)
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x=var_dram, y="rating", data=data)
fig.axis(ymin=0, ymax=10);
plt.xticks(rotation=90);

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 9))
sns.distplot(df['rating'],ax = axs[0,0]);
sns.distplot(df['m_score'], ax = axs[0, 1]);
sns.distplot(df['vote'], ax= axs[1,0] );
sns.distplot( df['gross'], ax=axs[1,1]);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#scatter plot m_score/rating

var_m_score = 'm_score'
data = pd.concat([df['rating'], df[var_m_score]], axis=1)
data.plot.scatter(x='rating', y=var_m_score);

# %%
#scatter plot vote/rating

var_vote = 'vote'
data = pd.concat([df[var_vote],df['rating']], axis=1)
data.plot.scatter(x='rating', y=var_vote);

# %%
#scatter plot gross/rating

var_gross = 'gross'
data = pd.concat([df['rating'], df[var_gross]], axis=1)
data.plot.scatter(x='rating', y=var_gross);

# %%
#correlation matrix

corrmat = df.corr()
corrmat = corrmat.fillna(0)
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# # **Features Selection**

# %%
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'rating')['rating'].index
cm = df[cols].corr()
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values, cmap='Blues')
plt.show()

# %%
#scatterplot

sns.set()
cols = ['rating', 'm_score', 'vote'] 
sns.pairplot(df[cols], size = 3)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df_cols_selected = df.loc[:, cols]
df_cols_selected.head(5)
# Out:
#    rating  m_score       vote
# 0     8.6     85.0  1294962.0
# 1     8.5     75.0  1008750.0
# 2     8.0     95.0   421130.0
# 3     6.8     52.0   238177.0
# 4     6.9     51.0   180551.0

# %%
df_cols_selected.describe()
# Out:
#              rating      m_score          vote
# count  12161.000000  8274.000000  1.101600e+04
# mean       6.257109    55.649746  5.677488e+04
# std        1.067379    17.225767  1.356972e+05
# min        1.400000     1.000000  5.000000e+00
# 25%        5.700000    43.000000  2.098750e+03
# 50%        6.400000    56.000000  1.006300e+04
# 75%        7.000000    68.000000  4.938925e+04
# max        9.400000   100.000000  2.385759e+06

# %% [markdown]
# # **Missing Values Handling**

# %%
mis_val = df.isnull().sum()
mis_val_percent = 100 * df.isnull().sum() / len(df)
mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
mis_val_table_ren_columns = mis_val_table_ren_columns[mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
mis_val_table_ren_columns
# Out:
#          Missing Values  % of Total Values
# m_score            3887               32.0
# vote               1145                9.4
# gross              1145                9.4

# %%
msno.bar(df)

# %%
msno.matrix(df)

# %%
msno.matrix(df.sample(1000))

# %%
sorted = df.sort_values('m_score')
msno.matrix(sorted)

# %%
msno.heatmap(df)

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# rating      0
# m_score     0
# vote        0
# gross       0
# act         0
# advent      0
# anima       0
# biogr       0
# come        0
# crime       0
# docum       0
# dram        0
# fami        0
# fant        0
# film_nor    0
# game_sh     0
# hist        0
# horr        0
# mus         0
# musc        0
# myst        0
# news        0
# real_tv     0
# rom         0
# sci_f       0
# spo         0
# talksh      0
# thrill      0
# war         0
# west        0
# non_t       0
# dtype: int64

# %%
df_train = pd.DataFrame(df,columns=['rating','m_score','vote'])
df_train.tail(10)
# Out:
#        rating  m_score      vote
# 12137     6.3     60.0    2318.0
# 12138     6.8     55.0  121063.0
# 12142     6.7     63.0   37027.0
# 12145     5.5     39.0   10282.0
# 12149     7.3     62.0  436818.0
# 12152     6.7     81.0   74044.0
# 12153     6.6     82.0     294.0
# 12156     7.0     77.0  143314.0
# 12158     6.5     42.0   21938.0
# 12159     4.7     40.0    1807.0

# %% [markdown]
# # **Data Normalization**

# %%
df_train['vote']= np.log(df_train['vote'])
df_train
# Out:
#        rating  m_score       vote
# 0         8.6     85.0  14.073992
# 1         8.5     75.0  13.824222
# 2         8.0     95.0  12.950697
# 3         6.8     52.0  12.380769
# 4         6.9     51.0  12.103769
# ...       ...      ...        ...
# 12152     6.7     81.0  11.212415
# 12153     6.6     82.0   5.683580
# 12156     7.0     77.0  11.872793
# 12158     6.5     42.0   9.995976
# 12159     4.7     40.0   7.499423
#
# [8217 rows x 3 columns]

# %%
sns.distplot(df_train['vote']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
min_max = MinMaxScaler() 
df_train = pd.DataFrame(min_max.fit_transform(df_train),columns=df_train.columns) 
df_train.head()
# Out:
#      rating   m_score      vote
# 0  0.911392  0.848485  0.951069
# 1  0.898734  0.747475  0.931068
# 2  0.835443  0.949495  0.861118
# 3  0.683544  0.515152  0.815479
# 4  0.696203  0.505051  0.793298

# %%
#correlation matrix

corrmat = df_train.corr()
corrmat = corrmat.fillna(0)
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1, square=True);

# %%
k = 3 #number of variables for heatmap
cols = corrmat.nlargest(k, 'rating')['rating'].index
cm = df[cols].corr()
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values, cmap='Blues')
plt.show()

# %%
df_train.isnull().sum()
# Out:
# rating     0
# m_score    0
# vote       0
# dtype: int64

# %% [markdown]
# # **Out liar Handling**

# %%
fig = plt.figure(figsize=(6,6))
sns.boxplot(y = df_train['m_score'])

# %%
sns.distplot(df_train['m_score']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(6,6))
sns.boxplot(y = df_train['rating'])

# %%
sns.distplot(df_train['rating']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(12,8))
sns.regplot(df_train['rating'],df_train['m_score'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_rating_02_04 = df_train.loc[(df_train['rating'] >= 0.0) & (df_train['rating'] <= 0.3)]
df_mscr_05_07 = df_rating_02_04.loc[(df_rating_02_04['m_score'] >= 0.55) & (df_rating_02_04['m_score'] <= 0.7)]
df_train = df_train.drop(df_mscr_05_07.index)

# %%
fig = plt.figure(figsize=(12,8))
sns.regplot(df_train['rating'],df_train['m_score'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # **Data Modeling**

# %%
X0 = np.array([df_train['m_score'].values])
X1 = np.array([df_train['vote'].values])
X = np.concatenate((X0.T,X1.T, np.ones((X0.shape[1], 1))), axis=1)
#,np.ones((X0.shape[1], 1)))
y = np.array(df_train['rating'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=50)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.08, random_state=50)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (6045, 3)
# (1643, 3)
# (526, 3)

# %% [markdown]
# **Linear Regression**

# %%
regr = linear_model.LinearRegression(fit_intercept=False) # fit_intercept = False for calculating the bias
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, n_jobs=None, normalize=False)

# %%
y_pred = regr.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 0.07744643568015827

# %%
x = np.arange(0, y_test.shape[0])

# %%
fig = plt.figure(figsize=(12,8))
start = 0
end = 80
plt.plot(x[start:end], (y_test[start:end]))
plt.plot(x[start:end], (y_pred[start:end]))
plt.legend(['actual', 'predict'], loc='upper right')
plt.show()

# %%
from sklearn import metrics
np.sqrt(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.07744643568015827

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.0059979503995608915

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.5393099588876914

# %%
sns.regplot(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **USING NEUTRAL NETWORK**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
import keras

# %%
model = Sequential([
        Dense(32, activation = 'relu'),  #32 neurons, Input Layer, 'relu' activation
        Dense(32, activation = 'relu'),  #32 neurons, Hidden Layer, 'relu' activation
        Dense(32, activation = 'relu'),  #32  neurons, Hidden Layer, 'relu' activation
        Dense(1)                         #Output Layer
    ])                                                      
optimizer = keras.optimizers.Adam(learning_rate=0.01)
model.compile(
        loss='mse',  #Trained using Mean square error loss (Cost function) 
        optimizer=optimizer  #Optimizer used is 'adam' (One of the Fastest optimizers)
    )

# %%
filepath="/content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-{epoch:02d}-{val_loss:.5f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

history = model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    batch_size=32,
    epochs = 100, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 189/189 [==============================] - 1s 2ms/step - loss: 0.0151 - val_loss: 0.0061
#
# Epoch 00001: val_loss improved from inf to 0.00607, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-01-0.00607.hdf5
# Epoch 2/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0061
#
# Epoch 00002: val_loss improved from 0.00607 to 0.00605, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-02-0.00605.hdf5
# Epoch 3/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0070 - val_loss: 0.0065
#
# Epoch 00003: val_loss did not improve from 0.00605
# Epoch 4/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0067 - val_loss: 0.0060
#
# Epoch 00004: val_loss improved from 0.00605 to 0.00598, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-04-0.00598.hdf5
# Epoch 5/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0060
#
# Epoch 00005: val_loss did not improve from 0.00598
# Epoch 6/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0062
#
# Epoch 00006: val_loss did not improve from 0.00598
# Epoch 7/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0069 - val_loss: 0.0059
#
# Epoch 00007: val_loss improved from 0.00598 to 0.00591, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-07-0.00591.hdf5
# Epoch 8/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0066 - val_loss: 0.0060
#
# Epoch 00008: val_loss did not improve from 0.00591
# Epoch 9/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0065 - val_loss: 0.0061
#
# Epoch 00009: val_loss did not improve from 0.00591
# Epoch 10/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0061
#
# Epoch 00010: val_loss did not improve from 0.00591
# Epoch 11/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0074
#
# Epoch 00011: val_loss did not improve from 0.00591
# Epoch 12/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0065 - val_loss: 0.0072
#
# Epoch 00012: val_loss did not improve from 0.00591
# Epoch 13/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0061
#
# Epoch 00013: val_loss did not improve from 0.00591
# Epoch 14/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0059
#
# Epoch 00014: val_loss did not improve from 0.00591
# Epoch 15/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0060
#
# Epoch 00015: val_loss did not improve from 0.00591
# Epoch 16/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0061
#
# Epoch 00016: val_loss did not improve from 0.00591
# Epoch 17/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0060
#
# Epoch 00017: val_loss did not improve from 0.00591
# Epoch 18/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0057
#
# Epoch 00018: val_loss improved from 0.00591 to 0.00574, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-18-0.00574.hdf5
# Epoch 19/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0059
#
# Epoch 00019: val_loss did not improve from 0.00574
# Epoch 20/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0066
#
# Epoch 00020: val_loss did not improve from 0.00574
# Epoch 21/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0059
#
# Epoch 00021: val_loss did not improve from 0.00574
# Epoch 22/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0066
#
# Epoch 00022: val_loss did not improve from 0.00574
# Epoch 23/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0057
#
# Epoch 00023: val_loss improved from 0.00574 to 0.00568, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-23-0.00568.hdf5
# Epoch 24/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0059
#
# Epoch 00024: val_loss did not improve from 0.00568
# Epoch 25/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0057
#
# Epoch 00025: val_loss did not improve from 0.00568
# Epoch 26/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0065
#
# Epoch 00026: val_loss did not improve from 0.00568
# Epoch 27/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0065 - val_loss: 0.0063
#
# Epoch 00027: val_loss did not improve from 0.00568
# Epoch 28/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00028: val_loss did not improve from 0.00568
# Epoch 29/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0060
#
# Epoch 00029: val_loss did not improve from 0.00568
# Epoch 30/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00030: val_loss did not improve from 0.00568
# Epoch 31/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0059
#
# Epoch 00031: val_loss did not improve from 0.00568
# Epoch 32/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00032: val_loss did not improve from 0.00568
# Epoch 33/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0060
#
# Epoch 00033: val_loss did not improve from 0.00568
# Epoch 34/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00034: val_loss did not improve from 0.00568
# Epoch 35/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0059
#
# Epoch 00035: val_loss did not improve from 0.00568
# Epoch 36/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0058
#
# Epoch 00036: val_loss did not improve from 0.00568
# Epoch 37/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00037: val_loss did not improve from 0.00568
# Epoch 38/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00038: val_loss did not improve from 0.00568
# Epoch 39/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00039: val_loss did not improve from 0.00568
# Epoch 40/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0057
#
# Epoch 00040: val_loss improved from 0.00568 to 0.00567, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-40-0.00567.hdf5
# Epoch 41/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00041: val_loss did not improve from 0.00567
# Epoch 42/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0061
#
# Epoch 00042: val_loss did not improve from 0.00567
# Epoch 43/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00043: val_loss did not improve from 0.00567
# Epoch 44/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0064 - val_loss: 0.0057
#
# Epoch 00044: val_loss did not improve from 0.00567
# Epoch 45/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0069
#
# Epoch 00045: val_loss did not improve from 0.00567
# Epoch 46/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0058
#
# Epoch 00046: val_loss did not improve from 0.00567
# Epoch 47/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00047: val_loss did not improve from 0.00567
# Epoch 48/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0060
#
# Epoch 00048: val_loss did not improve from 0.00567
# Epoch 49/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00049: val_loss did not improve from 0.00567
# Epoch 50/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00050: val_loss did not improve from 0.00567
# Epoch 51/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00051: val_loss did not improve from 0.00567
# Epoch 52/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00052: val_loss improved from 0.00567 to 0.00566, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-52-0.00566.hdf5
# Epoch 53/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0060
#
# Epoch 00053: val_loss did not improve from 0.00566
# Epoch 54/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00054: val_loss did not improve from 0.00566
# Epoch 55/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00055: val_loss did not improve from 0.00566
# Epoch 56/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00056: val_loss did not improve from 0.00566
# Epoch 57/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0063
#
# Epoch 00057: val_loss did not improve from 0.00566
# Epoch 58/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0062
#
# Epoch 00058: val_loss did not improve from 0.00566
# Epoch 59/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0058
#
# Epoch 00059: val_loss did not improve from 0.00566
# Epoch 60/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00060: val_loss did not improve from 0.00566
# Epoch 61/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00061: val_loss did not improve from 0.00566
# Epoch 62/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00062: val_loss improved from 0.00566 to 0.00562, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-62-0.00562.hdf5
# Epoch 63/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0059
#
# Epoch 00063: val_loss did not improve from 0.00562
# Epoch 64/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00064: val_loss did not improve from 0.00562
# Epoch 65/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00065: val_loss did not improve from 0.00562
# Epoch 66/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00066: val_loss did not improve from 0.00562
# Epoch 67/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00067: val_loss did not improve from 0.00562
# Epoch 68/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00068: val_loss did not improve from 0.00562
# Epoch 69/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00069: val_loss did not improve from 0.00562
# Epoch 70/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0060
#
# Epoch 00070: val_loss did not improve from 0.00562
# Epoch 71/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00071: val_loss did not improve from 0.00562
# Epoch 72/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0058
#
# Epoch 00072: val_loss did not improve from 0.00562
# Epoch 73/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00073: val_loss did not improve from 0.00562
# Epoch 74/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0059
#
# Epoch 00074: val_loss did not improve from 0.00562
# Epoch 75/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0059
#
# Epoch 00075: val_loss did not improve from 0.00562
# Epoch 76/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00076: val_loss did not improve from 0.00562
# Epoch 77/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00077: val_loss did not improve from 0.00562
# Epoch 78/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00078: val_loss did not improve from 0.00562
# Epoch 79/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00079: val_loss did not improve from 0.00562
# Epoch 80/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0062
#
# Epoch 00080: val_loss did not improve from 0.00562
# Epoch 81/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00081: val_loss did not improve from 0.00562
# Epoch 82/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00082: val_loss did not improve from 0.00562
# Epoch 83/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00083: val_loss did not improve from 0.00562
# Epoch 84/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00084: val_loss did not improve from 0.00562
# Epoch 85/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00085: val_loss improved from 0.00562 to 0.00560, saving model to /content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-85-0.00560.hdf5
# Epoch 86/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0059
#
# Epoch 00086: val_loss did not improve from 0.00560
# Epoch 87/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0065
#
# Epoch 00087: val_loss did not improve from 0.00560
# Epoch 88/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00088: val_loss did not improve from 0.00560
# Epoch 89/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0059
#
# Epoch 00089: val_loss did not improve from 0.00560
# Epoch 90/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00090: val_loss did not improve from 0.00560
# Epoch 91/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0060
#
# Epoch 00091: val_loss did not improve from 0.00560
# Epoch 92/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00092: val_loss did not improve from 0.00560
# Epoch 93/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0059
#
# Epoch 00093: val_loss did not improve from 0.00560
# Epoch 94/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00094: val_loss did not improve from 0.00560
# Epoch 95/100
# 189/189 [==============================] - 0s 1ms/step - loss: 0.0062 - val_loss: 0.0057
#
# Epoch 00095: val_loss did not improve from 0.00560
# Epoch 96/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0057
#
# Epoch 00096: val_loss did not improve from 0.00560
# Epoch 97/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0056
#
# Epoch 00097: val_loss did not improve from 0.00560
# Epoch 98/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0058
#
# Epoch 00098: val_loss did not improve from 0.00560
# Epoch 99/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0060
#
# Epoch 00099: val_loss did not improve from 0.00560
# Epoch 100/100
# 189/189 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0059
#
# Epoch 00100: val_loss did not improve from 0.00560

# %%
fig = plt.figure(figsize=(12,8))
df_his = pd.DataFrame(history.history) 
plt.plot(df_his.loc[0:100,['loss']]) # training error
plt.plot(df_his.loc[0:100,['val_loss']], color='orange') # validation error
plt.legend(['train', 'validation'], loc='upper right')

# %%
model.load_weights('/content/drive/MyDrive/Tiểu luận khoa học dữ liệu /Implementation/Model Check Point/weights-63-0.00567.hdf5')

# %%
y_nn_pred = model.predict(X_test)

# %%
fig = plt.figure(figsize=(12,8))
start = 0
end = 80
plt.plot(x[start:end], (y_test[start:end]))
plt.plot(x[start:end], (y_nn_pred[start:end]), color='orange')
plt.legend(['actual', 'predict'], loc='upper right')
plt.show()

# %%
np.sqrt(metrics.mean_squared_error(y_test, y_nn_pred))
# Out:
# 0.07538226914051896

# %%
mean_squared_error(y_test, y_nn_pred)
# Out:
# 0.005682486500773637

# %%
metrics.r2_score(y_test, y_nn_pred)
# Out:
# 0.5635400819831391

# %%
sns.regplot(y_test, y_nn_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
fig = plt.figure(figsize=(12,8))
start = 0
end = 80
plt.plot(x[start:end], (y_test[start:end]))
plt.plot(x[start:end], (y_pred[start:end]), color='black')
plt.plot(x[start:end], (y_nn_pred[start:end]), color='orange')
plt.legend(['actual', 'predict_linear_regression', 'predict_neural_network'], loc='lower left')
plt.show()
